# %% [markdown]
# # Assignment 2
#
# #### 문제 1. 다음 6 개의 Expression에 대해 Evaluation 결과 값을 출력하고, 해당 결과가 나온 이유에 대해 설명하시오.

# %%
print 1 and 2 and 3 and 4
print 1 or 2 or 3 or 4
print 1 and 2 or 3 and 4
print (1 and 2) or (3 and 4)
print 1 or 2 and 3 or 4
print (1 or 2) and (3 or 4)
# Out:
# 4
# 1
# 2
# 2
# 1
# 3

# %% [markdown]
# 설명
# 1. 1 and 2 and 3 and 4는 1이 참이므로 2가 실행되고 2가 참이므로 3이 실행, 3이 참이므로 4가 실행되어 4가 출력된다.
# 2. 1 or 2 or 3 or 4는 1이 참인데 or 이므로 뒤에는 볼 필요가 없다. 따라서 1이 출력된다.
# 3. 1 and 2 or 3 and 4는 1이 참이므로 2가 실행된 상태에서 or를 만나므로 뒤에는 볼 필요없이 2가 출력된다.
# 4. (1 and 2) or (3 and 4)는 1과 2의 and 연산을 먼저 했을 때 2가 출력되고 3과 4의 and연산을 했을 때 4가 출력되는데 그럼 2 or 4가 되므로 2가 참이므로 or 연산은 할 필요가 없다. 따라서 2가 출력된다.
# 5. 1 or 2 and 3 or 4는 1 or 2에서 1이 참이므로 뒤에는 아예 무시한다. 그러므로 1이 출력된다.
# 6. (1 or 2) and (3 or 4)는 1과 2의 or 연산에서 1이 출력되고, 3과 4의 or연산에서 3이 출력된 상태에서 1 and 3 연산이므로 3이 출력된다.

# %% [markdown]
# #### 문제 2. 경로에 해당하는 문자열 1개를 입력 받아 그 안에 디렉토리 경로명과 파일명을 분리하여 리스트로 반환하는 함수 div_path(s)를 작성하시오.
# - 인자로 전달하는 문자열은 경로만 들어간다고 가정한다.
# - 각 디렉토리와 파일을 구분하는 문자는 '/'로 가정한다.
# - 반환하는 리스트의 첫번째 원소는 디렉토리이고 두번째 원소는 파일명이다.
# - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - div_path('/usr/local/bin/python')
#         - ['/usr/local/bin', 'python']
#     - div_path('/home/chulsoo/test.txt')
#         - ['/home/chulsoo', 'test.txt']
# - [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.

# %%
def div_path(s):   
    s = s.split('/')
    
    b = s[:-1]
    x = ['/'.join(b)]
    
    s = x.append(s[-1])
    return x

print div_path('/usr/local/bin/python')
print div_path('/home/chulsoo/test.txt')
# Out:
# ['/usr/local/bin', 'python']
# ['/home/chulsoo', 'test.txt']

# %% [markdown]
# 설명
# 1. 먼저 문자열을 '/' 에 대해서 분리하고, 문자열에서 맨 뒤에서 앞에 있는 문자열까지만 '/'로 다시 묶는다. 그리고 분리했던 문자열에 맨 마지막 문자열을 추가해주어 리스트로 출력하면 된다.

# %% [markdown]
# #### 문제 3. 두 개의 리스트를 인자로 받아서 그 두 개의 리스트에 대한 '합집합'을 반환하는 함수 list_union(lista, listb)를 작성하시오.
# - 인자로 전달하는 리스트 2 개에는 정수값만 들어간다고 가정하자.
# - 함수 내에서 새로운 리스트를 만들어 그 리스트 내에 인자로 받은 두 리스트의 모든 원소를 넣어 반환한다.
# - 반환하는 리스트에는 절대로 중복된 원소가 들어 있으면 안된다 (집합의 조건).
# - 반환하는 리스트는 정렬이 되어 있어야 한다.
# - 다음과 같은 실행 및 출력 결과가 도출되어야 한다.
#     - list_union([1, 2, 3], [1, 2, 4])
#     - [1, 2, 3, 4]
#     - list_union([-10, -5, 0, -1], [100, 9, 0, 9])
#     - [-10, -5, -1, 0, 9, 100]
#     - list_union([0, 1, 2], [0, 1, 2])
#     - [0, 1, 2]
# - [참고] 리스트(l) 내에 새로운 정수값 (예를 들어 10)을 넣는 방법은 l.append(10) 이다.
# - [참고] 임의의 정수값 (x)이 리스트 (l) 내에 존재하는지 판단하는 방법은 x in l 이다.

# %%
def list_union(lista, listb):
    for x in range(0, len(lista)):
        if listb[x] in lista:
            continue
        else:
            lista.append(listb[x])
    lista.sort()        
    return lista

print list_union([1, 2, 3], [1, 2, 4])
print list_union([-10, -5, 0, -1], [100, 9, 0, 9])
print list_union([0, 1, 2], [0, 1, 2])
# Out:
# [1, 2, 3, 4]
# [-10, -5, -1, 0, 9, 100]
# [0, 1, 2]

# %% [markdown]
# 설명
# 1. lista에 있는 리스트 원소들의 수만큼 반복문을 사용해 lista에 있는 원소들이 listb에 있는지 판단하고 있으면 넘어가고 없다면 lista에 listb에 있는 원소를 추가하여 정렬한 뒤에 그 리스트를 반환하여 출력하면 된다.

# %% [markdown]
# ### 프로젝트 오일러 4.
# #### 앞에서부터 읽을 때나 뒤에서부터 읽을 때나 모양이 같은 수를 대칭수(palindrome)라고 부릅니다.
# #### 두 자리 수를 곱해 만들 수 있는 대칭수 중 가장 큰 수는 9009 (= 91 × 99) 입니다.
# #### 세 자리 수를 곱해 만들 수 있는 가장 큰 대칭수는 얼마입니까?

# %%
def palindrome(n):
    length = len(str(n))/2
    for i in range(0, length):
        if str(n)[i] != str(n)[-i-1]:
            return 0
    return 1
result = 0
for a in range(100, 1000):
    for b in range(100, 1000):
        if palindrome(a * b):
            result = max(result, a*b)
print result
# Out:
# 906609

# %% [markdown]
# 설명
# 1. palindrome() 함수에서 매개변수를 문자열로 변환하여 그 값을 변수에 넣어준다. 그 값을 반복문에 넣어 문자열의 처음과 맨 뒤의 문자를 비교하여 다르면 0을 반환하고, 같으면 1을 반환한다. 세자리 수의 곱이므로 이중 for문을 통하여 곱한 값을 palindrome 함수의 매개변수로 받아서 결과값을 출력하면 된다. (이 문제는 인터넷을 참고하여 해결했습니다.)

# %% [markdown]
# ### 프로젝트 오일러 5.
# #### 1 ~ 10 사이의 어떤 수로도 나누어 떨어지는 가장 작은 수는 2520입니다. 그러면 1 ~ 20 사이의 어떤 수로도 나누어 떨어지는 가장 작은 수는 얼마입니까?

# %%
def div(num):
    for x in range(1, 20):
        if num % x != 0:
            return 1
 
num = 21
while(1):
    if div(num) == 1:
        num = num + 1
    else:     
        print num
        break
# Out:
# 232792560

# %% [markdown]
# 설명
# 1. div라는 함수는 입력받은 어떤수를 1부터 20사이에 있는 수로 나누었을 때 0이 아닐경우에 1을 반환하는 함수이다.
# 2. num을 21로 선언하고 무한루프에 들어가면 함수를 호출하여 그 반환값이 1이면 0으로 num이 나눠떨어지지 않으므로 num을 증가시키고 다시 조건문에 들어가고 계속 반복하다가 반환값이 1이 아니면 그 숫자를 출력하고 무한루프를 끝낸다.

# %% [markdown]
# ### 프로젝트 오일러 6.
# 1부터 10까지 자연수를 각각 제곱해 더하면 다음과 같습니다 (제곱의 합).
#
#     - 1^2 + 2^2 + ... + 10^2 = 385
# 1부터 10을 먼저 더한 다음에 그 결과를 제곱하면 다음과 같습니다 (합의 제곱).
#
#     - (1 + 2 + ... + 10)^2 = 552 = 3025
# 따라서 1부터 10까지 자연수에 대해 "합의 제곱"과 "제곱의 합" 의 차이는 3025 - 385 = 2640 이 됩니다.
#
# 그러면 1부터 100까지 자연수에 대해 "합의 제곱"과 "제곱의 합"의 차이는 얼마입니까?

# %%
mult = 0
sum = 0
summult = 0
multsum = 0

for a in range(1, 101):
    sum = sum + a
    summult = sum*sum
for b in range(1, 101):
    mult = mult + b * b

print summult
print mult

print summult - mult
# Out:
# 25502500
# 338350
# 25164150

# %% [markdown]
# 설명
# 1. 합과 곱, 합의 제곱과 제곱의 합을 구하기 위한 변수를 선언한 후, 반복문을 통해서 각각 합의 제곱과 제곱의 합을 구한다. sum이라는 변수에 1부터 100까지 수를 다 더한값을 넣고 sum을 한 번 더 곱해주면 합의 제곱이 된다. 그리고 다른 for문에서 mult라는 변수에 1부터 100까지 제곱한 값과 mult의 합을 넣으면 제곱의 합이 출력된다. 그러고 마지막으로 합의 제곱과 제곱의 합의 차를 구하면 된다.

# %% [markdown]
# ### [Incremental Project]
# #### 웹 URL로 지정된 웹페이지를 문자열로 가져와 1) 모든 HTML 태그를 제외한 순수 텍스트 문자열만을 걸러내고, 2) 그 순수 텍스트 문자열 안에 존재하는 단어가 총 몇개인지 출력하는 프로그램을 작성하시오.
# - HTML 태그는 다음 조건을 가지는 것이다.
#     - < 로 시작하여 >로 끝난다.
#     - 예를 들어, 아래와 같은 HTML 내용 내에 한 줄이 있다고 가정하자.
#       <label for="keep_signed">로그인 유지</label>
#     - 위 소스에서 HTML 태그를 제외한 순수 텍스트 문자열은 아래와 같다.
#       로그인 유지
#     - 한편, 아래와 같은 HTML 한 줄이 있다고 가정하자.
#       <link rel="stylesheet" href="/common/css/xe.min.css?20150910092654" />
#
#     - 위 소스는 HTML 태그로만 구성된 것이며 걸러낼 수 있는 순수 텍스 문자열은 존재하지 않는다.
# - 단어를 나누는 기준은 오로지 공백문자 (whitespace)이다.
#
#     - 즉, 위 순수 텍스트 문자열인 "로그인 유지"에서 분리한 단어는 "로그인"과 "유지"이다.
# - 다음은 URL로 지정된 웹페이지를 특정 문자열로 가져오는 코드이다.
#     - 즉, 숙제 코드는 아래 코드로 부터 시작해야 한다.

# %%
import urllib2

source = urllib2.urlopen("http://cse.kut.ac.kr/").read()
print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- META -->
# <meta charset="utf-8">
# <meta name="Generator" content="XpressEngine">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <!-- TITLE -->
# <title>컴퓨터공학부</title>
# <!-- CSS -->
# <link rel="stylesheet" href="/common/css/xe.min.css?20160902161107" />
# <link rel="stylesheet" href="/layouts/cse/style/prettyPhoto.css?20150805222706" />
# <link rel="stylesheet" href="/layouts/cse/style/stylemobile.css?20150805222706" />
# <link rel="stylesheet" href="/layouts/cse/style/mobilenavigation.css?20150805222706" />
# <link rel="stylesheet" href="/modules/editor/styles/ckeditor_light/style.css?20160902161106" />
# <link rel="stylesheet" href="/widgets/login_info/skins/cse_login_info_2015/default.login.css?20150420232234" />
# <link rel="stylesheet" href="/widgets/content_cse/skins/cse_latest_2015/css/widget.css?20150625005943" />
# <link rel="stylesheet" href="/addons/font_nanum_gothic/font-nanum_gothic.css?20150429141819" />
# ...

# %%
for i in range(0,source.count("<!--")):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")
print source
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#
# <meta charset="utf-8">
# <meta name="Generator" content="XpressEngine">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <title>컴퓨터공학부</title>
#
# <link rel="stylesheet" href="/common/css/xe.min.css?20160902161107" />
# <link rel="stylesheet" href="/layouts/cse/style/prettyPhoto.css?20150805222706" />
# <link rel="stylesheet" href="/layouts/cse/style/stylemobile.css?20150805222706" />
# <link rel="stylesheet" href="/layouts/cse/style/mobilenavigation.css?20150805222706" />
# <link rel="stylesheet" href="/modules/editor/styles/ckeditor_light/style.css?20160902161106" />
# <link rel="stylesheet" href="/widgets/login_info/skins/cse_login_info_2015/default.login.css?20150420232234" />
# <link rel="stylesheet" href="/widgets/content_cse/skins/cse_latest_2015/css/widget.css?20150625005943" />
# <link rel="stylesheet" href="/addons/font_nanum_gothic/font-nanum_gothic.css?20150429141819" />
# ...

# %%
for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")
print source
# Out:
# 컴퓨터공학부
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# //
#
#
#
#
#
#
#
# 	Schoolfun - Study and Fun
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	로그인
#
# 		로그인
#
#
#
#
# 			아이디												비밀번호
#
#
#
# 				로그인 유지
#
# 			브라우저를 닫더라도 로그인이 계속 유지될 수 있습니다. 로그인 유지 기능을 사용할 경우 다음 접속부터는 로그인할 필요가 없습니다. 단, 게임방, 학교 등 공공장소에서 이용 시 개인정보가 유출될 수 있으니 꼭 로그아웃을 해주세요.
#
#
#
# 			회원가입
# 			ID/PW 찾기
#
#
#
#
#
# 				IT 교육의 글로벌 메카!한국기술교육대학교 컴퓨터공학부
#
#
#
#
# 		Close
#
#
#
#
#
#
#
#
# 										소개
#
#
#
# 										구성원소개
#
#
#
# 										학사안내
#
#
#
# 										입학
#
#                         학부
#                         대학원
#
#
#
#
# 										학부광장
#
#
#
# 										자료실
#
#
#
# 										대학원
#
#
#
# 										공학교육인증
#
#
#
# 										학부서비스
#
#
#
#
#                         			Registration
#
#
#
#
#
#
#
#
#             컴퓨터공학부
#                 School of Computer Science and Engineering
#
#
#
#                 IT 융합소프트웨어 인력양성사업
#                 CK (Creative Korea)-I
#
#
#
# ...

# %%
k = source.split() 

for word in k:
    print word
# Out:
# 컴퓨터공학부
# //
# Schoolfun
# -
# Study
# and
# Fun
# 로그인
# 로그인
# 아이디
# 비밀번호
# 로그인
# 유지
# 브라우저를
# 닫더라도
# 로그인이
# 계속
# 유지될
# 수
# 있습니다.
# 로그인
# 유지
# 기능을
# 사용할
# 경우
# 다음
# 접속부터는
# 로그인할
# 필요가
# 없습니다.
# 단,
# 게임방,
# 학교
# 등
# 공공장소에서
# 이용
# 시
# 개인정보가
# 유출될
# 수
# 있으니
# 꼭
# 로그아웃을
# 해주세요.
# 회원가입
# ID/PW
# 찾기
# IT
# 교육의
# 글로벌
# 메카!한국기술교육대학교
# 컴퓨터공학부
# Close
# 소개
# 구성원소개
# 학사안내
# 입학
# 학부
# 대학원
# 학부광장
# 자료실
# 대학원
# 공학교육인증
# 학부서비스
# Registration
# 컴퓨터공학부
# School
# of
# Computer
# Science
# and
# Engineering
# IT
# 융합소프트웨어
# 인력양성사업
# CK
# (Creative
# Korea)-I
# 교육역량강화사업
# 온라인
# 컨텐츠
# Online
# Contents
# for
# Education
# Capability
# Empowerment
# IT
# 교육의
# 글로벌
# 메카
# 한국기술교육대학교
# 컴퓨터공학부
# 홈페이지에
# 오신
# 것을환영합니다!
# IT
# 융합소프트웨어
# 인력양성사업
# 글로벌
# 수준의
# IT전문인력
# 양성
# IT융합분야에
# 대한
# 국제적인
# 경쟁력
# 고취
# 바로가기
# 교육역량강화사업
# 컨텐츠
# 교육역량강화사업
# 온라인
# 컨텐츠를
# 소개합니다.
# 바로가기
# 공지사항
# [특성화]
# 『G-Star
# 2016』전시회
# 참가
# 모집
# 공고
# 2016-10-10
# 01:00
# 01:00
# [특성화]
# 『요코하마
# 임베디드
# 기술
# 박람회』
# 학생
# 선...
# 2016-10-08
# 22:11
# ...

# %%
print len(k)
# Out:
# 449

# %% [markdown]
# 설명
# 1. 우선 cse.koreatech 홈페이지 소스를 가져온다. 그리고 난 후에 HTML에 사용되는 주석인 <!--와 --!>을 먼저 제거하기 위해서 소스에 있는 <!--의 갯수를 먼저 카운트 한다. 그리고 처음 주석인 <!--을 만나게되면 -->위치가 나올때까지 그 위치를 찾고 -->길이 만큼 +3을 해주어 주석 안에 존재하는 내용을 모두 ""(삭제)로 대체 시킨다.
# 2. 주석이 다 제거되었으면 HTML 태그인 '<'의 위치를 찾아서 처음 만나게되는 <와 > 안에 있는 내용을 똑같이 ""(삭제)로 대체시킨다.
# 3. 태그를 모두 제거하게되면 소스에서 단어만 남게되는데 단어들 사이에 있는 모든 공백들을 제거하고 단어만 출력한다.
# 4. 출력된 단어의 개수를 세어 출력한다.
